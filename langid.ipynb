# %%
import py3langid as langid

# %%
import py3langid as langid

text = "Hello my name is David"
langid.classify(text)
# Out:
# ('en', -35.57076)

# %%
lang, prob = langid.classify(text)
langid.rank(text)
# Out:
# [('en', -35.57075881958008),
#  ('tl', -39.87000274658203),
#  ('af', -41.50590896606445),
#  ('la', -42.76983642578125),
#  ('br', -42.81480407714844),
#  ('it', -42.915870666503906),
#  ('es', -43.43187713623047),
#  ('zu', -46.012718200683594),
#  ('nl', -46.01786804199219),
#  ('gl', -47.068458557128906),
#  ('id', -47.602325439453125),
#  ('cy', -47.650146484375),
#  ('mg', -47.8521842956543),
#  ('eo', -47.98489761352539),
#  ('pt', -48.02342987060547),
#  ('an', -48.068145751953125),
#  ('sw', -48.13136291503906),
#  ('ga', -48.61697006225586),
#  ('hu', -48.82185745239258),
#  ('ms', -49.01154327392578),
#  ('sk', -49.2781867980957),
#  ('jv', -49.4085693359375),
#  ('pl', -49.487796783447266),
#  ('oc', -49.64221954345703),
#  ('sq', -49.76134490966797),
#  ('sl', -50.02569580078125),
#  ('ht', -50.05204772949219),
#  ('xh', -50.22433090209961),
#  ('hr', -50.29558181762695),
#  ('cs', -50.776519775390625),
#  ('se', -50.81100845336914),
#  ('de', -50.874603271484375),
#  ('bs', -51.005645751953125),
#  ('lb', -51.07720184326172),
#  ('rw', -51.43729782104492),
#  ('lt', -51.70067596435547),
#  ('no', -51.79607009887695),
#  ('lo', -52.085044860839844),
#  ('et', -52.479515075683594),
#  ('qu', -52.674278259277344),
#  ('fi', -52.71363067626953),
#  ('az', -53.789039611816406),
#  ('fr', -54.042415618896484),
#  ('ca', -54.15349197387695),
#  ('fo', -54.25840377807617),
#  ('ku', -54.35287094116211),
#  ('tr', -54.89849853515625),
#  ('nn', -55.03361511230469),
#  ('lv', -55.202510833740234),
#  ('is', -56.39807891845703),
#  ('da', -56.709251403808594),
#  ('vo', -57.11619186401367),
#  ('ar', -57.292320251464844),
#  ('ro', -57.51509094238281),
#  ('wa', -57.523494720458984),
#  ('he', -57.53069305419922),
#  ('nb', -57.62571334838867),
#  ('mt', -57.643470764160156),
#  ('sv', -58.019775390625),
#  ('eu', -58.30756759643555),
#  ('ky', -58.727821350097656),
#  ('zh', -58.95744705200195),
#  ('am', -60.768898010253906),
#  ('ko', -61.04094314575195),
#  ('ka', -61.15279006958008),
#  ('si', -61.432273864746094),
#  ('ps', -62.90230941772461),
#  ('vi', -62.93172073364258),
#  ('as', -63.78036117553711),
#  ('ur', -64.16914367675781),
#  ('km', -64.55640411376953),
#  ('ja', -64.77928161621094),
#  ('hy', -64.85449981689453),
#  ('bn', -64.96724700927734),
#  ('ug', -65.6574478149414),
#  ('or', -66.0426025390625),
#  ('kk', -66.43889617919922),
#  ('ml', -67.23847198486328),
#  ('fa', -67.87481689453125),
#  ('gu', -68.12619018554688),
#  ('ru', -68.16248321533203),
#  ('ta', -68.76873016357422),
#  ('mr', -69.3011474609375),
#  ('te', -69.50315856933594),
#  ('hi', -69.6418228149414),
#  ('sr', -69.83750915527344),
#  ('th', -69.88774871826172),
#  ('kn', -70.48017120361328),
#  ('mk', -70.82749938964844),
#  ('mn', -71.904296875),
#  ('pa', -72.02186584472656),
#  ('el', -72.47457122802734),
#  ('be', -72.70419311523438),
#  ('uk', -73.11302947998047),
#  ('bg', -75.61088562011719),
#  ('ne', -75.65918731689453),
#  ('dz', -80.18229675292969)]

# %%
text
# Out:
# ' this text is in english'
